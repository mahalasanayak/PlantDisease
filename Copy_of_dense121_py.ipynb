# %% [markdown]
# <a href="https://colab.research.google.com/github/mahalasanayak/PlantDisease/blob/main/Copy_of_dense121_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv 
import matplotlib.pyplot as plt
import os
import pickle
from collections import defaultdict

# %%
from keras.applications.densenet import DenseNet121
from keras.applications.densenet import preprocess_input
from keras.optimizers import Adam, SGD
from keras.models import Model, load_model
from keras.layers import *
from sklearn.model_selection import train_test_split
from keras.callbacks import *

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# %%
disease_types = ['Pepper__bell___Bacterial_spot','Pepper__bell___healthy','Potato___Early_blight','rice_leafsmut','Potato___healthy','Tomato_Bacterial_spot','Tomato_Early_blight','Tomato_Late_blight','rice_brown_spot','Tomato_Septoria_leaf_spot','Tomato_Spider_mites_Two_spotted_spider_mite','Tomato__Target_Spot','Tomato__Tomato_YellowLeaf__Curl_Virus','rice_leaf_blight','Tomato_healthy']
data_dir = '/content/drive/MyDrive/archive/PlantVillage'
train_dir = os.path.join(data_dir)

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
        
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])
train.tail()
# Out:
#                                                     File  ...    Disease Type
# 18473  Tomato_healthy/59e72cea-137e-4c76-ba58-8b60aab...  ...  Tomato_healthy
# 18474  Tomato_healthy/583238e5-392b-40ef-9bbe-be54bda...  ...  Tomato_healthy
# 18475  Tomato_healthy/5b2457f5-96d5-4bcd-8025-dc55e66...  ...  Tomato_healthy
# 18476  Tomato_healthy/5dbc2db5-5bb2-4a3c-9a90-d2228c1...  ...  Tomato_healthy
# 18477  Tomato_healthy/5d11d60f-fb4a-4178-9594-d017a0f...  ...  Tomato_healthy
#
# [5 rows x 3 columns]

# %%
# Randomize the order of training set
SEED = 42
train = train.sample(frac=1, random_state=SEED) 
train.index = np.arange(len(train)) # Reset indices
train.head()
# Out:
#                                                 File  ...                           Disease Type
# 0  Pepper__bell___healthy/78d6d5a4-9e5b-424d-890b...  ...                 Pepper__bell___healthy
# 1  Tomato_Early_blight/1c31e2e3-e314-47a8-86fe-e7...  ...                    Tomato_Early_blight
# 2  Tomato__Tomato_YellowLeaf__Curl_Virus/6ff8989b...  ...  Tomato__Tomato_YellowLeaf__Curl_Virus
# 3  Tomato_healthy/409c349a-7738-41fc-8a3a-844cd33...  ...                         Tomato_healthy
# 4  Tomato_Late_blight/8f0a83b5-357c-4fc3-ba27-583...  ...                     Tomato_Late_blight
#
# [5 rows x 3 columns]

# %%
# Plot a histogram
plt.hist(train['DiseaseID'])
plt.title('Frequency Histogram of Species')
plt.figure(figsize=(12, 12))
plt.show()

# %%
IMAGE_SIZE = 64

def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 18478it [2:58:30,  1.73it/s]
# Train Shape: (18478, 64, 64, 3)

# %%
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=15)

# %%
BATCH_SIZE = 64

# Split the train and validation sets 
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.2, random_state=SEED)

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 15))
for i in range(3):
    ax[i].set_axis_off()
    ax[i].imshow(X_train[i])
    ax[i].set_title(disease_types[np.argmax(Y_train[i])])

# %%
EPOCHS = 40
SIZE=64
N_ch=3

# %%
def build_densenet():
    densenet = DenseNet121(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = densenet(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(15,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    optimizer = Adam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %%
model = build_densenet()
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
# Generates batches of image data with data augmentation
datagen = ImageDataGenerator(rotation_range=360, # Degree range for random rotations
                        width_shift_range=0.2, # Range for random horizontal shifts
                        height_shift_range=0.2, # Range for random vertical shifts
                        zoom_range=0.2, # Range for random zoom
                        horizontal_flip=True, # Randomly flip inputs horizontally
                        vertical_flip=True) # Randomly flip inputs vertically

datagen.fit(X_train)
# Fits the model on batches with real-time data augmentation
hist = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, Y_val))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# 29097984/29084464 [==============================] - 0s 0us/step
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 3)         84
# _________________________________________________________________
# densenet121 (Functional)     (None, None, None, 1024)  7037504
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               262400
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# root (Dense)                 (None, 15)                3855
# =================================================================
# Total params: 7,308,963
# Trainable params: 7,222,755
# Non-trainable params: 86,208
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/40
# 230/230 - 145s - loss: 2.3434 - accuracy: 0.3881 - val_loss: 1.5099 - val_accuracy: 0.5352
#
# Epoch 00001: val_loss improved from inf to 1.50988, saving model to model.h5
# Epoch 2/40
# 230/230 - 51s - loss: 0.8935 - accuracy: 0.7311 - val_loss: 0.8623 - val_accuracy: 0.7251
#
# Epoch 00002: val_loss improved from 1.50988 to 0.86228, saving model to model.h5
# Epoch 3/40
# 230/230 - 52s - loss: 0.5466 - accuracy: 0.8302 - val_loss: 1.0850 - val_accuracy: 0.7238
#
# Epoch 00003: val_loss did not improve from 0.86228
# Epoch 4/40
# 230/230 - 52s - loss: 0.3923 - accuracy: 0.8762 - val_loss: 0.4409 - val_accuracy: 0.8636
#
# Epoch 00004: val_loss improved from 0.86228 to 0.44093, saving model to model.h5
# Epoch 5/40
# 230/230 - 52s - loss: 0.3353 - accuracy: 0.8937 - val_loss: 0.3148 - val_accuracy: 0.9069
#
# Epoch 00005: val_loss improved from 0.44093 to 0.31480, saving model to model.h5
# Epoch 6/40
# 230/230 - 51s - loss: 0.2651 - accuracy: 0.9153 - val_loss: 0.3600 - val_accuracy: 0.8942
#
# Epoch 00006: val_loss did not improve from 0.31480
# Epoch 7/40
# 230/230 - 51s - loss: 0.2393 - accuracy: 0.9210 - val_loss: 0.3923 - val_accuracy: 0.8723
#
# Epoch 00007: val_loss did not improve from 0.31480
# Epoch 8/40
# 230/230 - 51s - loss: 0.2041 - accuracy: 0.9346 - val_loss: 0.8119 - val_accuracy: 0.8323
#
# Epoch 00008: val_loss did not improve from 0.31480
# Epoch 9/40
# 230/230 - 52s - loss: 0.1890 - accuracy: 0.9368 - val_loss: 0.1113 - val_accuracy: 0.9627
#
# Epoch 00009: val_loss improved from 0.31480 to 0.11129, saving model to model.h5
# Epoch 10/40
# 230/230 - 51s - loss: 0.1640 - accuracy: 0.9471 - val_loss: 0.3121 - val_accuracy: 0.9099
#
# Epoch 00010: val_loss did not improve from 0.11129
# Epoch 11/40
# 230/230 - 51s - loss: 0.1585 - accuracy: 0.9497 - val_loss: 0.2368 - val_accuracy: 0.9275
#
# Epoch 00011: val_loss did not improve from 0.11129
# Epoch 12/40
# 230/230 - 51s - loss: 0.1437 - accuracy: 0.9553 - val_loss: 0.1857 - val_accuracy: 0.9435
#
# Epoch 00012: val_loss did not improve from 0.11129
# Epoch 13/40
# 230/230 - 51s - loss: 0.1280 - accuracy: 0.9585 - val_loss: 0.4295 - val_accuracy: 0.8761
#
# Epoch 00013: val_loss did not improve from 0.11129
# Epoch 14/40
# 230/230 - 51s - loss: 0.1235 - accuracy: 0.9600 - val_loss: 0.2370 - val_accuracy: 0.9302
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 00014: val_loss did not improve from 0.11129
# Epoch 15/40
# 230/230 - 51s - loss: 0.0970 - accuracy: 0.9683 - val_loss: 0.1232 - val_accuracy: 0.9619
#
# Epoch 00015: val_loss did not improve from 0.11129
# Epoch 16/40
# 230/230 - 51s - loss: 0.0933 - accuracy: 0.9687 - val_loss: 0.3367 - val_accuracy: 0.9188
#
# Epoch 00016: val_loss did not improve from 0.11129
# Epoch 17/40
# 230/230 - 51s - loss: 0.0761 - accuracy: 0.9763 - val_loss: 0.2671 - val_accuracy: 0.9356
#
# Epoch 00017: val_loss did not improve from 0.11129
# Epoch 18/40
# 230/230 - 52s - loss: 0.0820 - accuracy: 0.9728 - val_loss: 0.1054 - val_accuracy: 0.9675
#
# Epoch 00018: val_loss improved from 0.11129 to 0.10540, saving model to model.h5
# Epoch 19/40
# 230/230 - 51s - loss: 0.0802 - accuracy: 0.9728 - val_loss: 0.2755 - val_accuracy: 0.9226
#
# Epoch 00019: val_loss did not improve from 0.10540
# Epoch 20/40
# 230/230 - 51s - loss: 0.0761 - accuracy: 0.9753 - val_loss: 0.1841 - val_accuracy: 0.9467
#
# Epoch 00020: val_loss did not improve from 0.10540
# Epoch 21/40
# 230/230 - 51s - loss: 0.0725 - accuracy: 0.9755 - val_loss: 0.2526 - val_accuracy: 0.9234
#
# Epoch 00021: val_loss did not improve from 0.10540
# Epoch 22/40
# 230/230 - 52s - loss: 0.0718 - accuracy: 0.9766 - val_loss: 0.1152 - val_accuracy: 0.9632
#
# Epoch 00022: val_loss did not improve from 0.10540
# Epoch 23/40
# 230/230 - 51s - loss: 0.0662 - accuracy: 0.9793 - val_loss: 0.3573 - val_accuracy: 0.9121
#
# Epoch 00023: val_loss did not improve from 0.10540
# Epoch 24/40
# 230/230 - 51s - loss: 0.0641 - accuracy: 0.9795 - val_loss: 0.1554 - val_accuracy: 0.9518
#
# Epoch 00024: val_loss did not improve from 0.10540
# Epoch 25/40
# 230/230 - 52s - loss: 0.0615 - accuracy: 0.9794 - val_loss: 0.2307 - val_accuracy: 0.9380
#
# Epoch 00025: val_loss did not improve from 0.10540
# Epoch 26/40
# 230/230 - 51s - loss: 0.0655 - accuracy: 0.9796 - val_loss: 0.0878 - val_accuracy: 0.9719
#
# Epoch 00026: val_loss improved from 0.10540 to 0.08777, saving model to model.h5
# Epoch 27/40
# 230/230 - 51s - loss: 0.0588 - accuracy: 0.9800 - val_loss: 0.1760 - val_accuracy: 0.9481
#
# Epoch 00027: val_loss did not improve from 0.08777
# Epoch 28/40
# 230/230 - 51s - loss: 0.0545 - accuracy: 0.9821 - val_loss: 0.3038 - val_accuracy: 0.9326
#
# Epoch 00028: val_loss did not improve from 0.08777
# Epoch 29/40
# 230/230 - 51s - loss: 0.0566 - accuracy: 0.9819 - val_loss: 0.2584 - val_accuracy: 0.9291
#
# Epoch 00029: val_loss did not improve from 0.08777
# Epoch 30/40
# 230/230 - 51s - loss: 0.0585 - accuracy: 0.9814 - val_loss: 0.2144 - val_accuracy: 0.9405
#
# Epoch 00030: val_loss did not improve from 0.08777
# Epoch 31/40
# 230/230 - 51s - loss: 0.0507 - accuracy: 0.9838 - val_loss: 0.1388 - val_accuracy: 0.9610
#
# Epoch 00031: val_loss did not improve from 0.08777
# Epoch 32/40
# 230/230 - 51s - loss: 0.0515 - accuracy: 0.9840 - val_loss: 0.1968 - val_accuracy: 0.9475
#
# Epoch 00032: val_loss did not improve from 0.08777
# Epoch 33/40
# 230/230 - 51s - loss: 0.0497 - accuracy: 0.9846 - val_loss: 0.1502 - val_accuracy: 0.9556
#
# Epoch 00033: val_loss did not improve from 0.08777
# Epoch 34/40
# 230/230 - 52s - loss: 0.0494 - accuracy: 0.9849 - val_loss: 0.7081 - val_accuracy: 0.8179
#
# Epoch 00034: val_loss did not improve from 0.08777
# Epoch 35/40
# 230/230 - 52s - loss: 0.0470 - accuracy: 0.9851 - val_loss: 0.2019 - val_accuracy: 0.9491
#
# Epoch 00035: val_loss did not improve from 0.08777
# Epoch 36/40
# 230/230 - 52s - loss: 0.0456 - accuracy: 0.9843 - val_loss: 0.2852 - val_accuracy: 0.9218
#
# Epoch 00036: val_loss did not improve from 0.08777
# Epoch 37/40
# 230/230 - 51s - loss: 0.0444 - accuracy: 0.9860 - val_loss: 0.1811 - val_accuracy: 0.9513
#
# Epoch 00037: val_loss did not improve from 0.08777
# Epoch 38/40
# 230/230 - 51s - loss: 0.0429 - accuracy: 0.9854 - val_loss: 0.2339 - val_accuracy: 0.9413
#
# Epoch 00038: val_loss did not improve from 0.08777
# Epoch 39/40
# 230/230 - 51s - loss: 0.0452 - accuracy: 0.9859 - val_loss: 0.1745 - val_accuracy: 0.9470
#
# Epoch 00039: val_loss did not improve from 0.08777
# Epoch 40/40
# 230/230 - 51s - loss: 0.0407 - accuracy: 0.9878 - val_loss: 0.5660 - val_accuracy: 0.8777
#
# Epoch 00040: val_loss did not improve from 0.08777

# %%
#model = load_model('../output/kaggle/working/model.h5')
final_loss, final_accuracy = model.evaluate(X_val, Y_val)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# 116/116 [==============================] - 5s 42ms/step - loss: 0.5660 - accuracy: 0.8777
# Final Loss: 0.5659788250923157, Final Accuracy: 0.8777056336402893

# %%
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# Text(0.5, 144.41374999999996, 'Predicted')

# %%
# accuracy plot 
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# loss plot
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
pip install anvil-uplink
# Out:
# Collecting anvil-uplink
#   Downloading https://files.pythonhosted.org/packages/9a/65/776713490bfd5145ddb87834355bf7936bd233b273098e37dc12f1ac253c/anvil_uplink-0.3.36-py2.py3-none-any.whl (61kB)
#      |████████████████████████████████| 61kB 3.2MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from anvil-uplink) (0.16.0)
# Collecting argparse
#   Downloading https://files.pythonhosted.org/packages/f2/94/3af39d34be01a24a6e65433d19e107099374224905f1e0cc6bbe1fd22a2f/argparse-1.4.0-py2.py3-none-any.whl
# Collecting ws4py
#   Downloading https://files.pythonhosted.org/packages/53/20/4019a739b2eefe9282d3822ef6a225250af964b117356971bd55e274193c/ws4py-0.5.1.tar.gz (51kB)
#      |████████████████████████████████| 61kB 4.6MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from anvil-uplink) (1.15.0)
# Building wheels for collected packages: ws4py
#   Building wheel for ws4py (setup.py) ... done
#   Created wheel for ws4py: filename=ws4py-0.5.1-cp37-none-any.whl size=45230 sha256=f20372c25d3ea07a4e46b451ba3478ec0e0d97f16e069b72bb4034bccc63f2c3
#   Stored in directory: /root/.cache/pip/wheels/a2/6e/4e/8b0ae12fb9b8a05715256952cf7609a8ab86285fab99b88c68
# Successfully built ws4py
# Installing collected packages: argparse, ws4py, anvil-uplink
# Successfully installed anvil-uplink-0.3.36 argparse-1.4.0 ws4py-0.5.1

# %%
import anvil.server

anvil.server.connect("RBGQMAWH3WLJI2ANNHEZRU4I-MOJUD5XH2A6XM5FC")
# Out:
# Connecting to wss://anvil.works/uplink
# Anvil websocket open
# Connected to "Default environment (dev)" as SERVER

# %%
#testing disease prediction
from skimage import io
from keras.preprocessing import image
import anvil.media
import numpy as np
import matplotlib.pyplot as plt

@anvil.server.callable
def classify_image(file):
  with anvil.media.TempFile(file) as filename:
    img = image.load_img(filename, grayscale=False, target_size=(64, 64))
    show_img=image.load_img(filename, grayscale=False, target_size=(200, 200))
  disease_class = ['Pepper__bell___Bacterial_spot','Pepper__bell___healthy','Potato___Early_blight','rice_leafsmut','Potato___healthy','Tomato_Bacterial_spot','Tomato_Early_blight','Tomato_Late_blight','rice_brown_spot','Tomato_Septoria_leaf_spot','Tomato_Spider_mites_Two_spotted_spider_mite','Tomato__Target_Spot','Tomato__Tomato_YellowLeaf__Curl_Virus','rice_leaf_blight','Tomato_healthy']
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)
  #x = np.array(x, 'float32')
  x /= 255

  custom = model.predict(x)
  print(custom[0])



    #x = x.reshape([64, 64]);

    #plt.gray()
  plt.imshow(show_img)
  plt.show()

  a=custom[0]
  ind=np.argmax(a)
        
  print('Prediction:',disease_class[ind])
  return('Prediction:',disease_class[ind])
